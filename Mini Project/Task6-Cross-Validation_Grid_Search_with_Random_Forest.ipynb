# %% [markdown]
# **Run the following two cells before you begin.**

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_csv('cleaned_data.csv')

# %% [markdown]
# **Run the following 3 cells to create a list of features, create a train/test split, and instantiate a random forest classifier.**

# %%
features_response = df.columns.tolist()
items_to_remove = ['ID', 'SEX', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
                   'EDUCATION_CAT', 'graduate school', 'high school', 'none',
                   'others', 'university']
features_response = [item for item in features_response if item not in items_to_remove]
features_response
# Out:
# ['LIMIT_BAL',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_1',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'default payment next month']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df[features_response[:-1]].values,
    df['default payment next month'].values,
    test_size=0.2, random_state=24
)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=10, criterion='gini', max_depth=3,
    min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0,
    max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0,
    min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=None,
    random_state=4, verbose=0, warm_start=False, class_weight=None
)

# %% [markdown]
# **Create a dictionary representing the grid for the `max_depth` and `n_estimators` hyperparameters that will be searched. Include depths of 3, 6, 9, and 12, and 10, 50, 100, and 200 trees.**

# %%
rf_params = {'max_depth': [3,6,9,12], 'n_estimators': [10,50,100,200]}

# %% [markdown]
# ________________________________________________________________
# **Instantiate a `GridSearchCV` object using the same options that we have previously in this course, but with the dictionary of hyperparameters created above. Set `verbose=2` to see the output for each fit performed.**

# %%
from sklearn.model_selection import GridSearchCV
cv_rf_ex = GridSearchCV(rf, param_grid=rf_params, scoring='roc_auc',
                        n_jobs=None, iid=False, refit=True, cv=4, verbose=2,
                        pre_dispatch=None, error_score=np.nan, return_train_score=True)

# %% [markdown]
# ____________________________________________________
# **Fit the `GridSearchCV` object on the training data.**

# %%
cv_rf_ex.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 16 candidates, totalling 64 fits
# [CV] max_depth=3, n_estimators=10 ....................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.3s
# [CV] max_depth=3, n_estimators=10 ....................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.2s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.2s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.2s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   1.0s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   1.0s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   0.9s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   0.9s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] .................... max_depth=3, n_estimators=100, total=   1.9s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] .................... max_depth=3, n_estimators=100, total=   2.1s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] .................... max_depth=3, n_estimators=100, total=   2.1s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] .................... max_depth=3, n_estimators=100, total=   2.2s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] .................... max_depth=3, n_estimators=200, total=   4.6s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] .................... max_depth=3, n_estimators=200, total=   4.6s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] .................... max_depth=3, n_estimators=200, total=   4.9s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] .................... max_depth=3, n_estimators=200, total=   4.1s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ..................... max_depth=6, n_estimators=10, total=   0.3s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ..................... max_depth=6, n_estimators=10, total=   0.4s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ..................... max_depth=6, n_estimators=10, total=   0.3s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ..................... max_depth=6, n_estimators=10, total=   0.3s
# [CV] max_depth=6, n_estimators=50 ....................................
# [CV] ..................... max_depth=6, n_estimators=50, total=   1.6s
# [CV] max_depth=6, n_estimators=50 ....................................
# [CV] ..................... max_depth=6, n_estimators=50, total=   1.7s
# [CV] max_depth=6, n_estimators=50 ....................................
# [CV] ..................... max_depth=6, n_estimators=50, total=   1.6s
# [CV] max_depth=6, n_estimators=50 ....................................
# [CV] ..................... max_depth=6, n_estimators=50, total=   1.5s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] .................... max_depth=6, n_estimators=100, total=   3.2s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] .................... max_depth=6, n_estimators=100, total=   3.2s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] .................... max_depth=6, n_estimators=100, total=   3.1s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] .................... max_depth=6, n_estimators=100, total=   3.1s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] .................... max_depth=6, n_estimators=200, total=   6.3s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] .................... max_depth=6, n_estimators=200, total=   6.2s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] .................... max_depth=6, n_estimators=200, total=   6.1s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] .................... max_depth=6, n_estimators=200, total=   6.3s
# [CV] max_depth=9, n_estimators=10 ....................................
# [CV] ..................... max_depth=9, n_estimators=10, total=   0.4s
# [CV] max_depth=9, n_estimators=10 ....................................
# [CV] ..................... max_depth=9, n_estimators=10, total=   0.4s
# [CV] max_depth=9, n_estimators=10 ....................................
# [CV] ..................... max_depth=9, n_estimators=10, total=   0.4s
# [CV] max_depth=9, n_estimators=10 ....................................
# [CV] ..................... max_depth=9, n_estimators=10, total=   0.4s
# [CV] max_depth=9, n_estimators=50 ....................................
# [CV] ..................... max_depth=9, n_estimators=50, total=   2.2s
# [CV] max_depth=9, n_estimators=50 ....................................
# [CV] ..................... max_depth=9, n_estimators=50, total=   2.1s
# [CV] max_depth=9, n_estimators=50 ....................................
# [CV] ..................... max_depth=9, n_estimators=50, total=   2.2s
# [CV] max_depth=9, n_estimators=50 ....................................
# [CV] ..................... max_depth=9, n_estimators=50, total=   2.2s
# [CV] max_depth=9, n_estimators=100 ...................................
# [CV] .................... max_depth=9, n_estimators=100, total=   4.2s
# [CV] max_depth=9, n_estimators=100 ...................................
# [CV] .................... max_depth=9, n_estimators=100, total=   4.7s
# [CV] max_depth=9, n_estimators=100 ...................................
# [CV] .................... max_depth=9, n_estimators=100, total=   4.5s
# [CV] max_depth=9, n_estimators=100 ...................................
# [CV] .................... max_depth=9, n_estimators=100, total=   4.5s
# [CV] max_depth=9, n_estimators=200 ...................................
# [CV] .................... max_depth=9, n_estimators=200, total=   9.0s
# [CV] max_depth=9, n_estimators=200 ...................................
# [CV] .................... max_depth=9, n_estimators=200, total=   8.9s
# [CV] max_depth=9, n_estimators=200 ...................................
# [CV] .................... max_depth=9, n_estimators=200, total=   8.8s
# [CV] max_depth=9, n_estimators=200 ...................................
# [CV] .................... max_depth=9, n_estimators=200, total=   8.8s
# [CV] max_depth=12, n_estimators=10 ...................................
# [CV] .................... max_depth=12, n_estimators=10, total=   0.6s
# [CV] max_depth=12, n_estimators=10 ...................................
# [CV] .................... max_depth=12, n_estimators=10, total=   0.6s
# [CV] max_depth=12, n_estimators=10 ...................................
# [CV] .................... max_depth=12, n_estimators=10, total=   0.5s
# [CV] max_depth=12, n_estimators=10 ...................................
# [CV] .................... max_depth=12, n_estimators=10, total=   0.6s
# [CV] max_depth=12, n_estimators=50 ...................................
# [CV] .................... max_depth=12, n_estimators=50, total=   2.7s
# [CV] max_depth=12, n_estimators=50 ...................................
# [CV] .................... max_depth=12, n_estimators=50, total=   2.8s
# [CV] max_depth=12, n_estimators=50 ...................................
# [CV] .................... max_depth=12, n_estimators=50, total=   2.8s
# [CV] max_depth=12, n_estimators=50 ...................................
# [CV] .................... max_depth=12, n_estimators=50, total=   2.7s
# [CV] max_depth=12, n_estimators=100 ..................................
# [CV] ................... max_depth=12, n_estimators=100, total=   5.8s
# [CV] max_depth=12, n_estimators=100 ..................................
# [CV] ................... max_depth=12, n_estimators=100, total=   5.7s
# [CV] max_depth=12, n_estimators=100 ..................................
# [CV] ................... max_depth=12, n_estimators=100, total=   5.4s
# [CV] max_depth=12, n_estimators=100 ..................................
# [CV] ................... max_depth=12, n_estimators=100, total=   5.4s
# [CV] max_depth=12, n_estimators=200 ..................................
# [CV] ................... max_depth=12, n_estimators=200, total=  10.8s
# [CV] max_depth=12, n_estimators=200 ..................................
# [CV] ................... max_depth=12, n_estimators=200, total=  10.6s
# [CV] max_depth=12, n_estimators=200 ..................................
# [CV] ................... max_depth=12, n_estimators=200, total=  10.7s
# [CV] max_depth=12, n_estimators=200 ..................................
# [CV] ................... max_depth=12, n_estimators=200, total=  11.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:  3.9min finished
# c:\users\bhavana padala\appdata\local\programs\python\python37\lib\site-packages\sklearn\model_selection\_search.py:849: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# GridSearchCV(cv=4,
#              estimator=RandomForestClassifier(max_depth=3, n_estimators=10,
#                                               random_state=4),
#              iid=False,
#              param_grid={'max_depth': [3, 6, 9, 12],
#                          'n_estimators': [10, 50, 100, 200]},
#              pre_dispatch=None, return_train_score=True, scoring='roc_auc',
#              verbose=2)

# %% [markdown]
# ___________________________________________________________
# **Put the results of the grid search in a pandas DataFrame.**

# %%
cv_rf_ex_results_df = pd.DataFrame(cv_rf_ex.cv_results_)
cv_rf_ex_results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.210732      0.025604         0.012035        0.006912
# 1        0.918147      0.037188         0.031284        0.000077
# 2        2.007554      0.098674         0.061253        0.013962
# 3        4.412869      0.269663         0.127409        0.007823
# 4        0.338244      0.025847         0.013963        0.003431
# 5        1.549098      0.055510         0.039730        0.005267
# 6        3.080402      0.051172         0.073546        0.002640
# 7        6.052528      0.064411         0.144560        0.015786
# 8        0.421262      0.006842         0.011735        0.006775
# 9        2.125278      0.031546         0.051926        0.006114
# 10       4.376437      0.166372         0.102400        0.007064
# 11       8.669550      0.079077         0.179395        0.005812
# 12       0.550084      0.013000         0.015636        0.000003
# 13       2.680876      0.041941         0.059640        0.003664
# 14       5.452403      0.178439         0.127529        0.029274
# 15      10.528031      0.120794         0.233415        0.006135
#
#    param_max_depth param_n_estimators                                  params  \
# 0                3                 10    {'max_depth': 3, 'n_estimators': 10}
# 1                3                 50    {'max_depth': 3, 'n_estimators': 50}
# 2                3                100   {'max_depth': 3, 'n_estimators': 100}
# 3                3                200   {'max_depth': 3, 'n_estimators': 200}
# 4                6                 10    {'max_depth': 6, 'n_estimators': 10}
# 5                6                 50    {'max_depth': 6, 'n_estimators': 50}
# 6                6                100   {'max_depth': 6, 'n_estimators': 100}
# 7                6                200   {'max_depth': 6, 'n_estimators': 200}
# 8                9                 10    {'max_depth': 9, 'n_estimators': 10}
# 9                9                 50    {'max_depth': 9, 'n_estimators': 50}
# 10               9                100   {'max_depth': 9, 'n_estimators': 100}
# 11               9                200   {'max_depth': 9, 'n_estimators': 200}
# 12              12                 10   {'max_depth': 12, 'n_estimators': 10}
# 13              12                 50   {'max_depth': 12, 'n_estimators': 50}
# 14              12                100  {'max_depth': 12, 'n_estimators': 100}
# 15              12                200  {'max_depth': 12, 'n_estimators': 200}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.739183           0.746599           0.772127
# 1            0.748009           0.755878           0.779465
# 2            0.747221           0.753924           0.779195
# 3            0.747454           0.753057           0.777644
# 4            0.752905           0.758904           0.780036
# 5            0.760089           0.765251           0.788567
# 6            0.760964           0.765515           0.788793
# 7            0.761481           0.765319           0.787854
# 8            0.757853           0.755444           0.781544
# 9            0.763956           0.764420           0.786690
# 10           0.763872           0.765788           0.789016
# 11           0.764963           0.767541           0.790255
# 12           0.754513           0.751116           0.764061
# 13           0.763750           0.763663           0.780781
# 14           0.765665           0.765061           0.783413
# 15           0.765910           0.766963           0.785611
#
#     split3_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0            0.771322         0.757308        0.014656               15
# 1            0.771250         0.763651        0.012379               12
# 2            0.770937         0.762819        0.012811               13
# 3            0.771729         0.762471        0.012550               14
# 4            0.774017         0.766466        0.010980               11
# 5            0.778669         0.773144        0.011193                8
# 6            0.778936         0.773552        0.011004                7
# 7            0.779745         0.773600        0.010682                6
# 8            0.773823         0.767166        0.010899               10
# 9            0.780255         0.773830        0.009908                4
# 10           0.781199         0.774969        0.010530                3
# 11           0.782034         0.776199        0.010402                1
# 12           0.759223         0.757228        0.004884               16
# 13           0.778086         0.771570        0.007921                9
# 14           0.781119         0.773815        0.008493                5
# 15           0.783513         0.775499        0.009101                2
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0             0.767973            0.767158            0.760550
# 1             0.775241            0.774025            0.765732
# 2             0.774340            0.773598            0.766103
# 3             0.774453            0.773534            0.766139
# 4             0.795911            0.796476            0.793695
# 5             0.807081            0.805109            0.799176
# 6             0.808194            0.806130            0.800846
# 7             0.808276            0.806853            0.800682
# 8             0.854161            0.856197            0.850317
# 9             0.867242            0.871380            0.868213
# 10            0.872099            0.874119            0.870537
# 11            0.873807            0.874909            0.871185
# 12            0.922544            0.919157            0.926191
# 13            0.940170            0.943000            0.942297
# 14            0.942902            0.946968            0.946109
# 15            0.945018            0.949378            0.946415
#
#     split3_train_score  mean_train_score  std_train_score
# 0             0.763683          0.764841         0.002955
# 1             0.766947          0.770486         0.004191
# 2             0.766914          0.770238         0.003750
# 3             0.767404          0.770382         0.003653
# 4             0.796446          0.795632         0.001141
# 5             0.801229          0.803149         0.003113
# 6             0.803123          0.804573         0.002808
# 7             0.804006          0.804954         0.002906
# 8             0.852039          0.853178         0.002211
# 9             0.867390          0.868557         0.001672
# 10            0.871196          0.871988         0.001350
# 11            0.871246          0.872787         0.001619
# 12            0.914636          0.920632         0.004263
# 13            0.937049          0.940629         0.002315
# 14            0.942448          0.944607         0.001962
# 15            0.944689          0.946375         0.001851

# %% [markdown]
# **Find the best hyperparameters from the cross-validation.**

# %%
cv_rf_ex.best_params_
# Out:
# {'max_depth': 9, 'n_estimators': 200}

# %% [markdown]
# ________________________________________________________________________________________________________
# **Create a `pcolormesh` visualization of the mean testing score for each combination of hyperparameters.**
#
# <details>
#     <summary>Hint:</summary>
#     Remember to reshape the values of the mean testing scores to be a two-dimensional 4x4 grid.
# </details>

# %%
# Create a 5x5 grid
x, y = np.meshgrid(rf_params['max_depth'],rf_params['n_estimators'])
z = cv_rf_ex_results_df['mean_test_score'].values.reshape(4,4)

# %%
# Set color map to `plt.cm.jet`
color_map = plt.cm.jet

# %%
# Visualize pcolormesh
ax = plt.axes()
pcolor_ex = ax.pcolormesh(x, y, z,cmap=color_map)
plt.colorbar(pcolor_ex, label='Color scale')
ax.set_xlabel('X coordinate')
ax.set_ylabel('Y coordinate')
# Out:
# c:\users\bhavana padala\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0, 0.5, 'Y coordinate')

# %% [markdown]
# ________________________________________________________________________________________________________
# **Conclude which set of hyperparameters to use.**

# %%
# Create a dataframe of the feature names and importance
feat_imp_df = pd.DataFrame({
    'Feature name':features_response[:-1],
    'Importance':cv_rf_ex.best_estimator_.feature_importances_
})

# %%
# Sort values by importance
feat_imp_df.sort_values('Importance', ascending=False)
# Out:
#    Feature name  Importance
# 4         PAY_1    0.437439
# 0     LIMIT_BAL    0.059961
# 11     PAY_AMT1    0.059434
# 12     PAY_AMT2    0.045518
# 13     PAY_AMT3    0.043299
# 5     BILL_AMT1    0.042195
# 6     BILL_AMT2    0.041562
# 7     BILL_AMT3    0.037268
# 14     PAY_AMT4    0.034321
# 8     BILL_AMT4    0.034123
# 10    BILL_AMT6    0.033839
# 9     BILL_AMT5    0.032413
# 15     PAY_AMT5    0.030734
# 16     PAY_AMT6    0.029070
# 3           AGE    0.026774
# 1     EDUCATION    0.007545
# 2      MARRIAGE    0.004504
